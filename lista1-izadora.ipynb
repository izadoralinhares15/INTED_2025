# %% [markdown]
# <a href="https://colab.research.google.com/github/izadoralinhares15/INTED_2025/blob/main/izadora_linhares_martins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 Peça um número e informe se ele é maior que 10.
idade= int(input('Digite uma idade'))
if idade>10:
    print('maior de idade')
# Out:
# Digite uma idade16
# maior de idade

# %%
# 2 Peça um número inteiro e informe se ele é par.
número= int(input('digite um número'))
if número%2==0:
    print('par')
else:
    print('impar')
# Out:
# digite um número12
# par

# %%
#3 Peça um nome e informe se ele contém a letra "a".
nome= input('digite um nome')
if 'a' in nome.lower():
    print("o nome contém a letra 'a'")
else:
    print("o nome não contém a letra 'a'")
# Out:
# digite um nomeizadora
# o nome contém a letra 'a'

# %%
# 4 Peça um número e informe se ele é múltiplo de 5.
num1= int(input('digite um número'))
if num1%5==0:
  print("o num1 é multiplo de'5'")
else:
  print("o número não é multiplo de'5'")
# Out:
# digite um número625
# o num1 é multiplo de'5'

# %%
# 5 Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos).
temp= int(input('digite a temperatura atual em °C:'))
if temp>30:
  print('está quente')
else:
  print('está frio')
# Out:
# digite a temperatura atual em °C:16
# está frio

# %%
# 6 Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente.
ação= input("digite'S' para continuar ou 'N' para sair:")
if ação =='S':
  print("'S' continuar")
elif ação == 'N':
  print("'N' sair")
else:
  print("entrada invalida. por favor, digite 'S' ou 'N'")
# Out:
# digite'S' para continuar ou 'N' para sair:N
# 'N' sair

# %%
# 7 Peça um número e informe se ele é negativo, zero ou positivo.
num= int(input('digite um número'))
if num<0:
  print('número negativo')
elif num==0:
  print('número zerro')
else:
  print('número positivo')
# Out:
# digite um número12
# número positivo

# %%
# 8 Peça um número de 1 a 7 e informe o dia da semana correspondente.
num= int(input('digite um número de 1 a 7 informando o dia da semana correspondente:'))
if num==1:
  print('domingo')
elif num ==2:
  print('segunda-feira')
elif num ==3:
  print('terça-feira')
elif num ==4:
  print('quarta-feira')
elif num ==5:
  print('quinta-feira')
elif num ==6:
  print('sexta-feira')
elif num ==7:
  print('sabado')
else:
  print("número invalido, por favor, digite um número de 1 a 7.")
# Out:
# digite um número de 1 a 7 informando o dia da semana correspondente:5
# quinta-feira

# %%
# 9 Peça um ano e informe se ele é bissexto.
num= int(input('digite um ano e informe se é bissexto:'))
if (num % 4 == 0 and num %100 != 0) or (num % 400 == 0):
  print(f"{num}é um ano bissexto")
else:
  print(f"{num} não é um ano bissexto")
# Out:
# digite um ano e informe se é bissexto:26
# 26 não é um ano bissexto

# %%
# 10 Peça a quantidade de horas trabalhadas e o valor por hora. Se trabalhou até 40 horas, calcule o salário normalmente (horas × valor por hora). Se trabalhou mais de 40 horas, as horas extras devem ter um adicional de 50% (horas extras × valor por hora × 1.5)
horas_trabalhalistas=int(input('digite a quantidade de horas trabalhadas:'))
valor_por_hora= float(input('digite o valor por hora:'))
if horas_trabalhados <= 40:
  salario= horas_trabalhadas * valor_por_hora
  print(f"osalaria é:R$ {salario:.2f}")
else:
  horas_normais = 40
  horas_extras= horas_trabalhads -horas_normais
  salario_normal= horas_normais * valor_por_hora
  salario_extra = horas_extras * valor_por_hora * 1,5
  salario_total = salario_normal + salario_extra
  print(f"o salario é:R${salario_total:.2f}")
